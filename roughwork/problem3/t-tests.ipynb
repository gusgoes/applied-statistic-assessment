# %% [markdown]
# # $t$-Tests

# %%
#Numerical arrays.
import numpy as np

# Statistical functions.
import scipy.stats as stats

# Plotting.
import matplotlib.pyplot as plt

# Statistical plots.
import seaborn as sns

# %% [markdown]
# ## Motivation

# %%
# New axes.
fig, ax = plt.subplots()

# X values.
x = np.linspace(-4.0, 4.0, 1000)

# Two normal distributions.
ax.plot(x, stats.norm.pdf(x, 0.0, 1.0), label=r'$\mu = 0.0$')
ax.plot(x, stats.norm.pdf(x, 1.0, 1.0), label=r'$\mu = 1.0$')

ax.legend()

# %%
# New axes.
fig, ax = plt.subplots()

# X values.
x = np.linspace(-4.0, 4.0, 1000)

# Two normal distributions.
ax.plot(x, stats.norm.pdf(x, 0.0, 0.1), label=r'$\mu = 0.0$')
ax.plot(x, stats.norm.pdf(x, 1.0, 0.1), label=r'$\mu = 1.0$')

ax.legend();

# %% [markdown]
# ## Normal Samples
#
# [numpy.random.normal](https://numpy.org/doc/2.0/reference/random/generated/numpy.random.normal.html)

# %%
# Group A.
group_a = np.random.normal(5, 2, 30)

# Group B.
group_b = np.random.normal(6, 2, 30)

# Show.
group_a, group_b
# Out:
# (array([7.24745002, 5.34150516, 7.90244749, 6.09237956, 6.3451426 ,
#         3.97080217, 1.57608474, 6.90085939, 5.73401578, 5.66671706,
#         4.63187029, 8.83507894, 7.23814619, 5.49975187, 5.46261225,
#         4.17157896, 5.76256448, 6.66208787, 6.29249851, 2.76222861,
#         5.65738741, 4.0876971 , 5.4851369 , 4.55374039, 5.78532979,
#         4.28261966, 1.19028833, 5.90617344, 5.52593893, 3.51903343]),
#  array([6.18783952, 4.86471337, 8.31575686, 3.77074847, 3.26220625,
#         8.65256943, 4.09813893, 3.54833024, 7.68024831, 6.27292105,
#         5.1686393 , 6.1112529 , 9.77018089, 7.57123884, 6.00935024,
#         7.08686617, 5.634664  , 7.58747643, 5.01663056, 3.48342755,
#         3.39728022, 3.75019844, 6.70232854, 5.81882579, 7.55318828,
#         4.88801193, 6.93739538, 3.46059615, 6.33754286, 6.22564706]))

# %%
# Create an empty data frame.
fig, ax = plt.subplots(figsize=(10, 5))

# Create histogram.
ax.hist(group_a, bins=np.arange(11), color='blue', alpha=0.5, label='Group A')

# Create histogram.
ax.hist(group_b, bins=np.arange(11), color='green', alpha=0.5, label='Group B');

# %%
# Create a strip plot.
sns.stripplot(data=[group_a, group_b]);

# %%
# Box plot.
sns.boxplot(data=[group_a, group_b]);

# %% [markdown]
# ## Independent Samples $t$-Test
#
# [scipy.stats.
# ttest_ind](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html#ttest-ind)
#
# **Null Hypothesis:** the population means are equal.

# %%
# Perform a t-test.
stats.ttest_ind(group_a, group_b)
# Out:
# TtestResult(statistic=np.float64(-1.1294872168465206), pvalue=np.float64(0.2633421228533665), df=np.float64(58.0))

# %% [markdown]
# ## Paired Samples $t$-Test

# %%
# A group of normally distributed values.
group_a = np.random.normal(5, 0.2, 30)

# %%
# Histgoram.
plt.hist(group_a, color='blue', alpha=0.5, label='Group A');

# %%
# Strip plot.
sns.stripplot(data=[group_a]);

# %%
# A group of normally distributed values.
group_a = np.random.normal(5, 0.2, 30)

# Add normally distributed values.
group_b = group_a + np.random.normal(0.2, 0.1, 30)

# %%
# Strip plot.
sns.stripplot(data=[group_a, group_b]);

# %% [markdown]
# ### scipy.stats.ttest_rel
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_rel.html#ttest-rel

# %%
# Paired samples t-test.
stats.ttest_rel(group_a, group_b)
# Out:
# TtestResult(statistic=np.float64(-11.085884326703072), pvalue=np.float64(6.054345337601857e-12), df=np.int64(29))

# %% [markdown]
# ## End
